# %%
import os
import pandas as pd

# %%
folder_path = "stocks"

empty_files = []

for file in os.listdir(folder_path):
    file_path = os.path.join(folder_path, file)
    if os.path.isfile(file_path) and os.path.getsize(file_path) == 0:
        empty_files.append(file)

if empty_files:
    print("Puste pliki w folderze 'stocks':")
    for empty_file in empty_files:
        print(empty_file)
else:
    print("Brak pustych plików w folderze 'stocks'.")
# Out:
# Puste pliki w folderze 'stocks':
# arha.txt
# bml.txt
# dbe1.txt
# die1.txt
# fmf.txt
# gbk.txt
# k2h.txt
# lvc.txt
# mur2.txt
# r22.txt
# urt1.txt

# %%
folder_path = "stocks"

files = os.listdir(folder_path)

dfs = []

for file in files:
    if file.endswith(".txt"):  
        file_path = os.path.join(folder_path, file)
        if os.path.getsize(file_path) > 0:
            df = pd.read_csv(file_path)
            dfs.append(df)

if dfs:
    merged_df = pd.concat(dfs, ignore_index=True)

    merged_file_path = "merged.csv"
    merged_df.to_csv(merged_file_path, index=False)

    print("Zmergowane dane zostały zapisane do pliku:", merged_file_path)
else:
    print("Brak danych do zmergowania lub wszystkie pliki są puste.")
# Out:
# Zmergowane dane zostały zapisane do pliku: merged.csv

# %%
df = pd.read_csv("merged.csv")
df.head()
# Out:
#   <TICKER> <PER>    <DATE>  <TIME>  <OPEN>  <HIGH>   <LOW>  <CLOSE>    <VOL>  \
# 0      06N     D  19970612       0  85.849  85.849  85.849   85.849  18258.0
# 1      06N     D  19970613       0  90.764  90.764  90.764   90.764  18402.0
# 2      06N     D  19970616       0  86.668  86.668  86.668   86.668   8411.0
# 3      06N     D  19970617       0  78.148  78.148  78.148   78.148  10313.0
# 4      06N     D  19970618       0  75.363  75.363  75.363   75.363   8673.0
#
#    <OPENINT>
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
df = df.drop(columns=['<PER>', '<TIME>', '<OPENINT>'])

# %%
df = df.rename(columns={'<TICKER>': 'TICKER',
                        '<DATE>': 'DATE',
                        '<OPEN>': 'OPEN',
                        '<HIGH>': 'HIGH',  
                        '<LOW>': 'LOW',  
                        '<CLOSE>': 'CLOSE',
                        '<VOL>': 'VOL'})
df.head()
# Out:
#   TICKER      DATE    OPEN    HIGH     LOW   CLOSE      VOL
# 0    06N  19970612  85.849  85.849  85.849  85.849  18258.0
# 1    06N  19970613  90.764  90.764  90.764  90.764  18402.0
# 2    06N  19970616  86.668  86.668  86.668  86.668   8411.0
# 3    06N  19970617  78.148  78.148  78.148  78.148  10313.0
# 4    06N  19970618  75.363  75.363  75.363  75.363   8673.0

# %%
df['DATE'] = pd.to_datetime(df['DATE'], format='%Y%m%d')
df['DATE'] = df['DATE'].dt.strftime('%m.%d.%Y')
df.head()
# Out:
#   TICKER        DATE    OPEN    HIGH     LOW   CLOSE      VOL
# 0    06N  06.12.1997  85.849  85.849  85.849  85.849  18258.0
# 1    06N  06.13.1997  90.764  90.764  90.764  90.764  18402.0
# 2    06N  06.16.1997  86.668  86.668  86.668  86.668   8411.0
# 3    06N  06.17.1997  78.148  78.148  78.148  78.148  10313.0
# 4    06N  06.18.1997  75.363  75.363  75.363  75.363   8673.0

# %%
print("Ilość tickerów:", df['TICKER'].nunique())
df.info()
# Out:
# Ilość tickerów: 430
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1575097 entries, 0 to 1575096
# Data columns (total 7 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   TICKER  1575097 non-null  object
#  1   DATE    1575097 non-null  object
#  2   OPEN    1575097 non-null  float64
#  3   HIGH    1575097 non-null  float64
#  4   LOW     1575097 non-null  float64
#  5   CLOSE   1575097 non-null  float64
#  6   VOL     1575097 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 84.1+ MB

# %%
delta = (pd.to_datetime(df['DATE']).max() - pd.to_datetime(df['DATE']).min())
print("Przedział czasowy danych historycznych:\n", delta)
# Out:
# Przedział czasowy danych historycznych:
#  13587 days 00:00:00

# %%
mean_dict = {}

for key in df['TICKER'].unique():
    value = df[df['TICKER'] == key ]['VOL'].mean()
    mean_dict[key]= value


avaerage_s = pd.Series(mean_dict).transpose()
top10_s = avaerage_s.sort_values(ascending=False)[:10]

print("Top 10 spółek z najwyższą średnią wolumenu:", top10_s.index)
# Out:
# Top 10 spółek z najwyższą średnią wolumenu: Index(['SAN', 'GTN', 'TPE', 'OPL', 'PZU', 'PKO', 'ALE', 'PGE', 'PKN', 'CEZ'], dtype='object')

# %%
print(df[df['TICKER'] == 'SAN'].tail())


# Wybór danych tylko dla pierwszych 10 spółek z najwyższą średnią wolumenu
top10_tickers = top10_s.index
top10_data = df[df['TICKER'].isin(top10_tickers)]

# Obliczenie minimalnej i maksymalnej daty dla wybranych spółek
min_date = top10_data['DATE'].min()
max_date = top10_data['DATE'].max()

print("Minimalna data notowań dla wybranych spółek:", min_date)
print("Maksymalna data notowań dla wybranych spółek:", max_date)
# Out:
#         TICKER        DATE   OPEN    HIGH     LOW   CLOSE     VOL
# 1256423    SAN  03.11.2024  17.28  17.280  16.858  16.898  1938.0
# 1256424    SAN  03.12.2024  17.10  17.308  17.100  17.300  1361.0
# 1256425    SAN  03.13.2024  17.45  17.550  17.450  17.500  3925.0
# 1256426    SAN  03.14.2024  17.68  17.680  17.250  17.476  1759.0
# 1256427    SAN  03.15.2024  17.48  17.600  17.418  17.526  3630.0
# Minimalna data notowań dla wybranych spółek: 01.02.2001
# Maksymalna data notowań dla wybranych spółek: 12.31.2013

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, DateFormatter

# Wybór danych tylko dla pierwszych 10 spółek z najwyższą średnią wolumenu
top10_tickers = top10_s.index
top10_data = df[df['TICKER'].isin(top10_tickers)]

# Iteracja przez każdą ze spółek z top 10 i rysowanie wykresów dla każdej spółki
for ticker in top10_tickers:
    ticker_data = top10_data[top10_data['TICKER'] == ticker]
    plt.figure()  # Tworzenie nowego wykresu
    plt.plot(ticker_data['DATE'], ticker_data['CLOSE'])
    plt.title(f'Cena zamknięcia dla spółki {ticker}')
    plt.xlabel('Data')
    plt.ylabel('Cena zamknięcia')

    # Formatowanie dat na osi x - tylko jedna data na rok
    ax = plt.gca()
    ax.xaxis.set_major_locator(YearLocator())
    ax.xaxis.set_major_formatter(DateFormatter('%Y'))
    plt.xticks(rotation=45)  # Obrót etykiet osi x dla lepszej czytelności dat

plt.tight_layout()  # Poprawa rozmieszczenia wykresów
plt.show()
